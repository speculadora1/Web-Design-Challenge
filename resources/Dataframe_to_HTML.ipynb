# %%
# import dependencies
import pandas as pd

# %%
# read in data
filepath = "cities.csv"
city_data = pd.read_csv(filepath)

# %%
# preview data
city_data.head()
# Out:
#             City Country        Date  Latitude  Longitude  Max Temp  Humidity  \
# 0   Punta Arenas      CL  1579928831    -53.15     -70.92     48.20        87
# 1        Cloquet      US  1579928831     46.72     -92.46     32.00        79
# 2  Traverse City      US  1579928831     44.76     -85.62     34.00        86
# 3           Hofn      IS  1579928635     64.25     -15.21     35.42        97
# 4         Cairns      AU  1579928635    -16.92     145.77     89.01        74
#
#    Wind Speed  Cloudiness
# 0       12.75          20
# 1       10.29         100
# 2        4.70          90
# 3       52.61         100
# 4        3.36          61

# %%
# format data as html table
print(pd.DataFrame.to_html(city_data, index = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>City</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Wind Speed</th>
#       <th>Cloudiness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Punta Arenas</td>
#       <td>CL</td>
#       <td>1579928831</td>
#       <td>-53.15</td>
#       <td>-70.92</td>
#       <td>48.20</td>
#       <td>87</td>
#       <td>12.75</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>Cloquet</td>
#       <td>US</td>
#       <td>1579928831</td>
#       <td>46.72</td>
#       <td>-92.46</td>
#       <td>32.00</td>
#       <td>79</td>
#       <td>10.29</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <td>Traverse City</td>
#       <td>US</td>
#       <td>1579928831</td>
#       <td>44.76</td>
#       <td>-85.62</td>
#       <td>34.00</td>
# ...
